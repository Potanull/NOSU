# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from celluloid import Camera
import matplotlib.animation

plt.rcParams["animation.html"] = "jshtml"
from matplotlib.animation import FuncAnimation

# %matplotlib inline

sns.set(style="darkgrid")

# %%
N = 10
L = 10

delta_t = L / N

alpha = 1.0/2.0

# %%
f = lambda t, y : 2 * y**2 + (2*t**(2-alpha) / math.gamma(3 - alpha))
u0 = lambda t : t**2

# %%
web = np.zeros(N)
x = np.linspace(0, L, num = N)
g = (x[1]**(1-alpha) - x[0]**(1-alpha))
d = (x[2]**(1-alpha) - 2*x[1]**(1-alpha) + x[0]**(1-alpha)) 

web[0] = u0(x[0])
web[1] = (math.gamma(2 - alpha) * delta_t * f(x[1], web[0])) / (x[1]**(1-alpha) - x[0]**(1-alpha)) + web[0]

for n in range(1, N - 2):
    web[n + 1] = (math.gamma(2 - alpha) * delta_t * f(x[n], web[n])) / (x[n]**(1-alpha) - x[n - 1]**(1-alpha))
    s = 0
    for m in range(0, n - 1):
        if(m == 0):
            s += (x[1]**(1-alpha) - x[0]**(1-alpha)) * web[m]
        else:
            s += (x[m + 1]**(1-alpha) - 2*x[m]**(1-alpha) + x[m - 1]**(1-alpha)) * web[m]
        
    web[n + 1] += (x[1]**(1-alpha) - x[0]**(1-alpha))**(0.5) * s

web[N - 1] = web[N - 2] + (math.gamma(2 - alpha) * delta_t) / (x[1]**(1-alpha) - x[0]**(1-alpha)) * f(x[n], web[N - 2])

# %%
print(web)
# Out:
# [0.00000000e+000 1.48148148e+000 5.17201068e+000 1.18706406e+002
#  7.45719187e+004 3.48975046e+010 8.67456807e+021 5.92861436e+044
#  3.01139226e+090 1.52486308e+181]
# 1.0540925533894598

# %%
camera = Camera(plt.figure(figsize = (20,8), dpi = 80))
plt.plot(x, web)
